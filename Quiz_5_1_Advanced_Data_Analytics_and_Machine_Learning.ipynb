# %%
import pandas as pd
import numpy as np

exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
examDf = pd.DataFrame(exam_data)
examDf.head(10)
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
examDf.count()
# Out:
# name        10
# score        8
# attempts    10
# qualify     10
# dtype: int64

# %%
cols = examDf.columns
print(cols)

x = examDf.last_valid_index()
# add 1 since indexing starts with 0
finalRowCount = x + 1
print("There are a total of ", finalRowCount, "rows.")
# Out:
# Index(['name', 'score', 'attempts', 'qualify'], dtype='object')
# There are a total of  10 rows.
